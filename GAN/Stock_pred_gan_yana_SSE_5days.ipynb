# %% [markdown]
# Load data from yahoo finance

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.59)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.6.3)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.9)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
from datetime import datetime
import yfinance as yf

# %%
#Shanghai Composite Index
# ticker '000001.SS'
SSE=yf.download('000001.SS','2010-01-05',end='2021-01-05')
SSE=SSE.reset_index()
SSE.shape
# Out:
# [*********************100%***********************]  1 of 1 completed
# (2670, 7)

# %%
#(SSE['Close'].shift(1)/5+SSE['Close'].shift(2)/5+SSE['Close'].shift(3)/5+SSE['Close'].shift(4)/5+SSE['Close']/5)
SSE['MA5_close']=SSE['Close'].rolling( window=5,min_periods=1).mean()
SSE['STD5_close']=SSE['Close'].rolling( window=5,min_periods=1).std()

# %%
#fill nan
SSE['STD5_close'][0]=SSE['STD5_close'].mean()
SSE.head()
# Out:
#         Date         Open         High  ...  Volume    MA5_close  STD5_close
# 0 2010-01-05  3254.468018  3290.511963  ...  126200  3282.178955   31.942483
# 1 2010-01-06  3277.517090  3295.867920  ...  123600  3268.197021   19.773440
# 2 2010-01-07  3253.990967  3268.819092  ...  128600  3243.056641   45.734131
# 3 2010-01-08  3177.259033  3198.919922  ...   98400  3231.291748   44.136809
# 4 2010-01-11  3301.611084  3306.750000  ...  136400  3227.583398   39.112693
#
# [5 rows x 9 columns]

# %%
import torch
import torch.nn as nn 
from torch.utils.data import Dataset, DataLoader

class StockDataset(Dataset):

    def __init__(self, data, seq_len=5):

        super(StockDataset, self).__init__()

        self.names = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume','MA5_close','STD5_close']
        #self.dfs = [pd.read_csv(file, sep='\t', names=self.names) for file in files]
        self.data=data
        self.length = len(data) - seq_len
        self.seq_len = seq_len

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        
       

        new_idx = idx if idx < self.length else self.length-1
        
        data, target = self.generate_batch(self.data, self.seq_len, start_from=new_idx, batch_size=1)

        data = torch.from_numpy(data).type(torch.FloatTensor).squeeze()
        target = torch.from_numpy(target).type(torch.FloatTensor).squeeze()

        return data, target
    
    def count_number_of_samples(self, filepath, n_features):
        df = pd.read_csv(filepath)
        return len(df) - n_features - 1

    def generate_batch(self, dataframe, seq_len, start_from, batch_size):

        data = []
        target = []

        bs = min(batch_size, len(dataframe) - start_from)

        dataframe['Date'] = pd.to_datetime(dataframe['Date'])
        df = dataframe.sort_values('Date').drop('Date', axis=1)
        # next create ma5 and normaliosation !!!
        for column in ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume','MA5_close','STD5_close']:
          df[column]=(df[column]-df[column].rolling(window=5,min_periods=1).mean())/df[column].rolling(window=5,min_periods=1).std().fillna(1)
        for i in range(bs):
            tar = df['Close'][start_from + seq_len + i]
           
            data_row = df[start_from + i:start_from + seq_len + i].values
            
            target.append(tar)
            data.append(data_row)

        target = np.array(target).ravel()
        data = np.vstack([elem[None, ...] for elem in data])
        
       
        assert data.shape == (bs, seq_len, df.values.shape[1])
        

        assert target.shape == (bs,)

        return data, target

# %%
#  SSE (2670, 7)
bs=100 # batch size
horizon=5
#Divide into train and validation dataset
train_dataset=StockDataset(SSE[:2000])
val_dataset=StockDataset(SSE[2000:])

#creating dataloader 
train_loader = DataLoader(train_dataset, batch_size=bs, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=bs, shuffle=False)

# %%
for data, target in train_loader:
    print(data.shape)
    print(target.shape)
    break
# Out:
# torch.Size([100, 5, 8])
# torch.Size([100])

# %% [markdown]
# Models Generator and Discriminator

# %%
class Generator(nn.Module):
    def __init__(self,input_size=7, hidden_size=horizon):
        super().__init__()
        # input size: (seq_len, batch, input_size)
        #output of shape (seq_len, batch, num_directions * hidden_size):
        self.lstm=nn.LSTM(input_size=input_size,hidden_size=1,num_layers=1)
        #[bs,horizon,7]
        self.fulcon=nn.Sequential(nn.Linear(hidden_size,1,bias=True), nn.LeakyReLU(),nn.Dropout())
    def forward(self, input_seq):
        bs, seq_len=input_seq.shape[0], input_seq.shape[1]
        input_seq=input_seq.permute(1,0,2)
        out,_=self.lstm(input_seq)
        out=out.permute(1,0,2)
       
        out=out.reshape(bs,seq_len)
        y=self.fulcon(out)
        #[bs,1]
        return y

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
#DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")    
horizon=5 #predict for 5 days
generator=Generator(input_size=8, hidden_size=horizon)
bs=100
N_epochs=100
criteria=nn.BCEWithLogitsLoss()
Discriminator=nn.Sequential(
    nn.Linear(horizon+1,72,bias=True),
    nn.LeakyReLU(),
    nn.Linear(72,100,bias=True),
    nn.LeakyReLU(),
    nn.Linear(100,10,bias=True),
    nn.LeakyReLU(),
    nn.Linear(10,1,bias=True),
    #nn.Sigmoid()
    
)
Discriminator=Discriminator.to(device)
generator=generator.to(device)
D_opt = torch.optim.Adam(Discriminator.parameters(), lr=0.001, betas=(0.0, 0.999))
G_opt = torch.optim.Adam(generator.parameters(), lr=0.001, betas=(0.0, 0.999))

#Validation
val_dataset=StockDataset(SSE[2000:])
val_dataset.data=val_dataset.data.reset_index().drop('index',axis=1)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)

# %% [markdown]
# Training loop

# %%
lambda1=0.5
lambda2=0.5

train_loss_disc=[]
train_loss_gen=[]
for epoch in range(N_epochs):
    Discriminator.train()
    generator.train()
    for itera, batch in enumerate(train_loader):
        #now target is just close price

        X_data, target = batch 
        
        X_data=X_data.to(device)
        target=target.to(device)
        #data is normalised
        bs=target.shape[0]
        #zeroes??
        fake_labels=torch.zeros([bs, 1]).to(device)
        true_labels=torch.ones([bs, 1]).to(device)
        
        gen_output=generator(X_data).detach()
        #vector of close prices 
        sequnce_6days=torch.cat([X_data[:,:,3], gen_output], dim=1)
        
        D_gen_loss=criteria(Discriminator(sequnce_6days), fake_labels)
        # index of close price is 3 
        
        true_seqeunce=torch.cat([X_data[:,:,3], target[:, None]],axis=1)
        # true_seqeunce Size is [bs, seq_len+1]
  
        D_true_loss=criteria(Discriminator(true_seqeunce), true_labels)
        
        D_loss = D_true_loss+D_gen_loss
        
        D_opt.zero_grad()
        D_loss.backward()
        D_opt.step()
        
        if itera%5:
            #let us train generator:
            gen_output=generator(X_data)
            #target is close price 
            
            # gen_output [bs,1] target [bs,] is meaned over batche items
            G_mse=torch.mean((gen_output-target[:,None])**2)
            
            sequnce_6days=torch.cat([X_data[:,:,3], gen_output], dim=1)
            
            G_logloss=-criteria(Discriminator(sequnce_6days), fake_labels)
          
            G_loss= lambda1*G_logloss + lambda2*G_mse
          
            G_opt.zero_grad()
            G_loss.backward()
            G_opt.step()
        
        # model.eval()
        
        if itera%100:

            if itera%1000:
                print('Epoch:',epoch)
                print('train loss Discriminator',D_loss.item())
                print('train loss Generator',G_loss.item())
                
            train_loss_disc.append(D_loss.item())
            train_loss_gen.append(G_loss.item())
      
    generator.eval()
    Discriminator.eval()


    generated_seqeunce_val=[]
    target_seqeunce_val=[]
    with torch.no_grad():

      mae_test=0
      rmse_test=0
      mape_test=0
      ar_test=0
      for iter, batch in enumerate(val_loader):
          data, target=batch
          data = data.to(device)
          target = target.to(device)
          generator_output=generator(data).detach()         
          generator_output= generator_output.squeeze(0)
        
          generated_seqeunce_val.append(generator_output.item())  
          target_seqeunce_val.append(target.item()) 
          mae_test+=torch.mean(torch.abs(generator_output-target)).item()
          rmse_test += torch.sqrt(torch.mean((generator_output-target)**2)).item()
          mape_test+=torch.mean(torch.abs(generator_output-target)/(target+0.0000001)).item()
          if iter>0:
              if generated_seqeunce_val[iter]>generated_seqeunce_val[iter-1]:
                  ar_test+=target_seqeunce_val[iter]-target_seqeunce_val[iter-1]
          
      mae_test=mae_test/len(val_loader)
      rmse_test=rmse_test/len(val_loader)
      mape_test=mape_test/len(val_loader)
      ar_test=ar_test/(len(val_loader)-1)
      print('Epoch :',epoch,', MAE val: ',mae_test)
      print('Epoch :',epoch,', RMSE val: ',rmse_test)
      print('Epoch :',epoch,', MAPE val: ',mape_test)
      print('Epoch :',epoch,', AR val: ',ar_test)
# Out:
# Streaming output truncated to the last 5000 lines.
# train loss Generator 0.2540605366230011
# Epoch: 18
# train loss Discriminator 0.8741447329521179
# train loss Generator 0.43254154920578003
# Epoch: 18
# train loss Discriminator 0.6056251525878906
# train loss Generator 0.49582043290138245
# Epoch: 18
# train loss Discriminator 0.6343165636062622
# train loss Generator 0.3020228445529938
# Epoch: 18
# train loss Discriminator 0.6536587476730347
# train loss Generator 0.3020228445529938
# Epoch: 18
# train loss Discriminator 0.6166041493415833
# train loss Generator 0.5105819702148438
# Epoch: 18
# train loss Discriminator 0.5978331565856934
# train loss Generator 0.47266721725463867
# Epoch: 18
# train loss Discriminator 0.552618682384491
# train loss Generator 0.3966582417488098
# Epoch: 18
# train loss Discriminator 0.741046130657196
# train loss Generator 0.42190563678741455
# Epoch: 18
# train loss Discriminator 0.5927610993385315
# train loss Generator 0.42190563678741455
# Epoch: 18
# train loss Discriminator 0.536745011806488
# train loss Generator 0.4609100818634033
# Epoch: 18
# train loss Discriminator 0.614180862903595
# train loss Generator 0.48832178115844727
# Epoch: 18
# train loss Discriminator 0.5925474166870117
# train loss Generator 0.38039594888687134
# Epoch: 18
# train loss Discriminator 0.649355411529541
# train loss Generator 0.3950777053833008
# Epoch: 18
# train loss Discriminator 0.7425137162208557
# train loss Generator 0.3950777053833008
# Epoch: 18
# train loss Discriminator 0.7373071908950806
# train loss Generator 0.46262624859809875
# Epoch: 18
# train loss Discriminator 0.5870290994644165
# train loss Generator 0.49564677476882935
# Epoch: 18
# train loss Discriminator 0.5955063104629517
# train loss Generator 0.44891172647476196
# Epoch: 18
# train loss Discriminator 0.7929893732070923
# train loss Generator 0.34308260679244995
# Epoch : 18 , MAE val:  0.8924421053316752
# Epoch : 18 , RMSE val:  0.8924421053316752
# Epoch : 18 , MAPE val:  -0.3900720328162599
# Epoch : 18 , AR val:  -0.0592368718503879
# Epoch: 19
# train loss Discriminator 0.7160878777503967
# train loss Generator 0.4407793879508972
# Epoch: 19
# train loss Discriminator 0.5574337244033813
# train loss Generator 0.5019702911376953
# Epoch: 19
# train loss Discriminator 0.6185232400894165
# train loss Generator 0.3869735598564148
# Epoch: 19
# train loss Discriminator 0.5928436517715454
# train loss Generator 0.35642728209495544
# Epoch: 19
# train loss Discriminator 0.6824007034301758
# train loss Generator 0.35642728209495544
# Epoch: 19
# train loss Discriminator 0.5965704321861267
# train loss Generator 0.33464837074279785
# Epoch: 19
# train loss Discriminator 0.5891717672348022
# train loss Generator 0.42705434560775757
# Epoch: 19
# train loss Discriminator 0.5601775646209717
# train loss Generator 0.6120635271072388
# Epoch: 19
# train loss Discriminator 0.6766231060028076
# train loss Generator 0.4009367823600769
# Epoch: 19
# train loss Discriminator 0.6431237459182739
# train loss Generator 0.4009367823600769
# Epoch: 19
# train loss Discriminator 0.6436052918434143
# train loss Generator 0.4876852035522461
# Epoch: 19
# train loss Discriminator 0.6620821952819824
# train loss Generator 0.4874231517314911
# Epoch: 19
# train loss Discriminator 0.6289815306663513
# train loss Generator 0.44409847259521484
# Epoch: 19
# train loss Discriminator 0.647599995136261
# train loss Generator 0.3419076204299927
# Epoch: 19
# train loss Discriminator 0.6167974472045898
# train loss Generator 0.3419076204299927
# Epoch: 19
# train loss Discriminator 0.8130102157592773
# train loss Generator 0.41498202085494995
# Epoch: 19
# train loss Discriminator 0.7374750375747681
# train loss Generator 0.36595234274864197
# Epoch: 19
# train loss Discriminator 0.708608865737915
# train loss Generator 0.4704785943031311
# Epoch: 19
# train loss Discriminator 0.6757768392562866
# train loss Generator 0.5144028067588806
# Epoch : 19 , MAE val:  0.8908784297841104
# Epoch : 19 , RMSE val:  0.8908784297841104
# Epoch : 19 , MAPE val:  -0.41732080046374603
# Epoch : 19 , AR val:  -0.04852954693543949
# Epoch: 20
# train loss Discriminator 0.5444095730781555
# train loss Generator 0.5247778296470642
# Epoch: 20
# train loss Discriminator 0.5990060567855835
# train loss Generator 0.4090566337108612
# Epoch: 20
# train loss Discriminator 0.6759399175643921
# train loss Generator 0.4163382351398468
# Epoch: 20
# train loss Discriminator 0.7180719971656799
# train loss Generator 0.43407049775123596
# Epoch: 20
# train loss Discriminator 0.6797692775726318
# train loss Generator 0.43407049775123596
# Epoch: 20
# train loss Discriminator 0.6072393655776978
# train loss Generator 0.42349299788475037
# Epoch: 20
# train loss Discriminator 0.65439772605896
# train loss Generator 0.41475409269332886
# Epoch: 20
# train loss Discriminator 0.7011277675628662
# train loss Generator 0.5453852415084839
# Epoch: 20
# train loss Discriminator 0.747657060623169
# train loss Generator 0.26461872458457947
# Epoch: 20
# train loss Discriminator 0.6755669713020325
# train loss Generator 0.26461872458457947
# Epoch: 20
# train loss Discriminator 0.6822373867034912
# train loss Generator 0.4692220091819763
# Epoch: 20
# train loss Discriminator 0.5442599058151245
# train loss Generator 0.40345630049705505
# Epoch: 20
# train loss Discriminator 0.657308042049408
# train loss Generator 0.5997686386108398
# Epoch: 20
# train loss Discriminator 0.6062268614768982
# train loss Generator 0.40324658155441284
# Epoch: 20
# train loss Discriminator 0.6241700649261475
# train loss Generator 0.40324658155441284
# Epoch: 20
# train loss Discriminator 0.5762002468109131
# train loss Generator 0.5502133369445801
# Epoch: 20
# train loss Discriminator 0.6185073852539062
# train loss Generator 0.42480939626693726
# Epoch: 20
# train loss Discriminator 0.627666711807251
# train loss Generator 0.37295109033584595
# Epoch: 20
# train loss Discriminator 0.6554946899414062
# train loss Generator 0.32723069190979004
# Epoch : 20 , MAE val:  0.8887831505689125
# Epoch : 20 , RMSE val:  0.8887831505689125
# Epoch : 20 , MAPE val:  -0.43479707121456923
# Epoch : 20 , AR val:  -0.05103848807559999
# Epoch: 21
# train loss Discriminator 0.5547310709953308
# train loss Generator 0.456520140171051
# Epoch: 21
# train loss Discriminator 0.7617074251174927
# train loss Generator 0.40743473172187805
# Epoch: 21
# train loss Discriminator 0.5323825478553772
# train loss Generator 0.46078047156333923
# Epoch: 21
# train loss Discriminator 0.607101559638977
# train loss Generator 0.3945426940917969
# Epoch: 21
# train loss Discriminator 0.6916420459747314
# train loss Generator 0.3945426940917969
# Epoch: 21
# train loss Discriminator 0.5624593496322632
# train loss Generator 0.504041314125061
# Epoch: 21
# train loss Discriminator 0.6618170738220215
# train loss Generator 0.4068076014518738
# Epoch: 21
# train loss Discriminator 0.7001849412918091
# train loss Generator 0.3125183880329132
# Epoch: 21
# train loss Discriminator 0.6847125291824341
# train loss Generator 0.5102552175521851
# Epoch: 21
# train loss Discriminator 0.6685602068901062
# train loss Generator 0.5102552175521851
# Epoch: 21
# train loss Discriminator 0.6521698236465454
# train loss Generator 0.40134793519973755
# Epoch: 21
# train loss Discriminator 0.6853772401809692
# train loss Generator 0.5844787359237671
# Epoch: 21
# train loss Discriminator 0.633353590965271
# train loss Generator 0.48189157247543335
# Epoch: 21
# train loss Discriminator 0.5624905824661255
# train loss Generator 0.65813809633255
# Epoch: 21
# train loss Discriminator 0.6290637850761414
# train loss Generator 0.65813809633255
# Epoch: 21
# train loss Discriminator 0.6316325664520264
# train loss Generator 0.40042856335639954
# Epoch: 21
# train loss Discriminator 0.6864218711853027
# train loss Generator 0.3290846347808838
# Epoch: 21
# train loss Discriminator 0.6916859149932861
# train loss Generator 0.3290975093841553
# Epoch: 21
# train loss Discriminator 0.6124959588050842
# train loss Generator 0.45043104887008667
# Epoch : 21 , MAE val:  0.887649899468358
# Epoch : 21 , RMSE val:  0.887649899468358
# Epoch : 21 , MAPE val:  -0.4505797168387002
# Epoch : 21 , AR val:  -0.04273671487168162
# Epoch: 22
# train loss Discriminator 0.6416469812393188
# train loss Generator 0.3723466694355011
# Epoch: 22
# train loss Discriminator 0.6457325220108032
# train loss Generator 0.48960185050964355
# Epoch: 22
# train loss Discriminator 0.611579418182373
# train loss Generator 0.3678496778011322
# Epoch: 22
# train loss Discriminator 0.6399548649787903
# train loss Generator 0.5223663449287415
# Epoch: 22
# train loss Discriminator 0.7592775225639343
# train loss Generator 0.5223663449287415
# Epoch: 22
# train loss Discriminator 0.6576995849609375
# train loss Generator 0.4019489586353302
# Epoch: 22
# train loss Discriminator 0.6347357034683228
# train loss Generator 0.4234590232372284
# Epoch: 22
# train loss Discriminator 0.5413955450057983
# train loss Generator 0.5802061557769775
# Epoch: 22
# train loss Discriminator 0.6478977203369141
# train loss Generator 0.38404279947280884
# Epoch: 22
# train loss Discriminator 0.612540602684021
# train loss Generator 0.38404279947280884
# Epoch: 22
# train loss Discriminator 0.711362898349762
# train loss Generator 0.39027076959609985
# Epoch: 22
# train loss Discriminator 0.583439826965332
# train loss Generator 0.5000143051147461
# Epoch: 22
# train loss Discriminator 0.49478286504745483
# train loss Generator 0.40273386240005493
# Epoch: 22
# train loss Discriminator 0.8045601844787598
# train loss Generator 0.37917375564575195
# Epoch: 22
# train loss Discriminator 0.659550666809082
# train loss Generator 0.37917375564575195
# Epoch: 22
# train loss Discriminator 0.721621572971344
# train loss Generator 0.48611053824424744
# Epoch: 22
# train loss Discriminator 0.5747716426849365
# train loss Generator 0.5226441621780396
# Epoch: 22
# train loss Discriminator 0.7442362308502197
# train loss Generator 0.30488330125808716
# Epoch: 22
# train loss Discriminator 0.653404951095581
# train loss Generator 0.44737768173217773
# Epoch : 22 , MAE val:  0.8859157395423075
# Epoch : 22 , RMSE val:  0.8859157395423075
# Epoch : 22 , MAPE val:  -0.470493811226793
# Epoch : 22 , AR val:  -0.03807644783947
# Epoch: 23
# train loss Discriminator 0.5526025891304016
# train loss Generator 0.5702663660049438
# Epoch: 23
# train loss Discriminator 0.6791810393333435
# train loss Generator 0.5325422286987305
# Epoch: 23
# train loss Discriminator 0.6764298677444458
# train loss Generator 0.3741166591644287
# Epoch: 23
# train loss Discriminator 0.6067156791687012
# train loss Generator 0.43249690532684326
# Epoch: 23
# train loss Discriminator 0.6381552815437317
# train loss Generator 0.43249690532684326
# Epoch: 23
# train loss Discriminator 0.656396746635437
# train loss Generator 0.3940882682800293
# Epoch: 23
# train loss Discriminator 0.6511863470077515
# train loss Generator 0.4256419837474823
# Epoch: 23
# train loss Discriminator 0.5717942714691162
# train loss Generator 0.26845434308052063
# Epoch: 23
# train loss Discriminator 0.7616043090820312
# train loss Generator 0.4488855302333832
# Epoch: 23
# train loss Discriminator 0.5167651176452637
# train loss Generator 0.4488855302333832
# Epoch: 23
# train loss Discriminator 0.7237816452980042
# train loss Generator 0.3873082101345062
# Epoch: 23
# train loss Discriminator 0.6453564167022705
# train loss Generator 0.387528657913208
# Epoch: 23
# train loss Discriminator 0.7609547972679138
# train loss Generator 0.359654039144516
# Epoch: 23
# train loss Discriminator 0.6899833083152771
# train loss Generator 0.45134615898132324
# Epoch: 23
# train loss Discriminator 0.686131477355957
# train loss Generator 0.45134615898132324
# Epoch: 23
# train loss Discriminator 0.6145671606063843
# train loss Generator 0.4515027403831482
# Epoch: 23
# train loss Discriminator 0.5513545870780945
# train loss Generator 0.42448174953460693
# Epoch: 23
# train loss Discriminator 0.47760921716690063
# train loss Generator 0.4346936345100403
# Epoch: 23
# train loss Discriminator 0.6058870553970337
# train loss Generator 0.5754160284996033
# Epoch : 23 , MAE val:  0.8837993108429351
# Epoch : 23 , RMSE val:  0.8837993108429351
# Epoch : 23 , MAPE val:  -0.48181134247522156
# Epoch : 23 , AR val:  -0.04048337046855062
# Epoch: 24
# train loss Discriminator 0.5711637735366821
# train loss Generator 0.42148345708847046
# Epoch: 24
# train loss Discriminator 0.7911822199821472
# train loss Generator 0.3933574855327606
# Epoch: 24
# train loss Discriminator 0.630233883857727
# train loss Generator 0.33142197132110596
# Epoch: 24
# train loss Discriminator 0.5730000138282776
# train loss Generator 0.531867504119873
# Epoch: 24
# train loss Discriminator 0.6686258316040039
# train loss Generator 0.531867504119873
# Epoch: 24
# train loss Discriminator 0.6310915946960449
# train loss Generator 0.3836974501609802
# Epoch: 24
# train loss Discriminator 0.5664390325546265
# train loss Generator 0.4514859914779663
# Epoch: 24
# train loss Discriminator 0.6311007738113403
# train loss Generator 0.3521570563316345
# Epoch: 24
# train loss Discriminator 0.5705481171607971
# train loss Generator 0.4782261252403259
# Epoch: 24
# train loss Discriminator 0.5314126014709473
# train loss Generator 0.4782261252403259
# Epoch: 24
# train loss Discriminator 0.6033975481987
# train loss Generator 0.3802885413169861
# Epoch: 24
# train loss Discriminator 0.635321319103241
# train loss Generator 0.42265084385871887
# Epoch: 24
# train loss Discriminator 0.6785398721694946
# train loss Generator 0.3381527066230774
# Epoch: 24
# train loss Discriminator 0.6403713226318359
# train loss Generator 0.48701611161231995
# Epoch: 24
# train loss Discriminator 0.6137971878051758
# train loss Generator 0.48701611161231995
# Epoch: 24
# train loss Discriminator 0.5511658191680908
# train loss Generator 0.4055628776550293
# Epoch: 24
# train loss Discriminator 0.6791541576385498
# train loss Generator 0.4468403458595276
# Epoch: 24
# train loss Discriminator 0.6779781579971313
# train loss Generator 0.4204685091972351
# Epoch: 24
# train loss Discriminator 0.7437993288040161
# train loss Generator 0.49051740765571594
# Epoch : 24 , MAE val:  0.8819992007771716
# Epoch : 24 , RMSE val:  0.8819992007771716
# Epoch : 24 , MAPE val:  -0.4938761350467689
# Epoch : 24 , AR val:  -0.03716011057609232
# Epoch: 25
# train loss Discriminator 0.7228318452835083
# train loss Generator 0.3330632746219635
# Epoch: 25
# train loss Discriminator 0.5528011322021484
# train loss Generator 0.4743276834487915
# Epoch: 25
# train loss Discriminator 0.6361962556838989
# train loss Generator 0.4622272551059723
# Epoch: 25
# train loss Discriminator 0.6646114587783813
# train loss Generator 0.5136707425117493
# Epoch: 25
# train loss Discriminator 0.6599664688110352
# train loss Generator 0.5136707425117493
# Epoch: 25
# train loss Discriminator 0.8136246204376221
# train loss Generator 0.4495598375797272
# Epoch: 25
# train loss Discriminator 0.6120144128799438
# train loss Generator 0.45969846844673157
# Epoch: 25
# train loss Discriminator 0.5571449398994446
# train loss Generator 0.4030603766441345
# Epoch: 25
# train loss Discriminator 0.6540298461914062
# train loss Generator 0.4494762420654297
# Epoch: 25
# train loss Discriminator 0.710828423500061
# train loss Generator 0.4494762420654297
# Epoch: 25
# train loss Discriminator 0.6024836897850037
# train loss Generator 0.6064974069595337
# Epoch: 25
# train loss Discriminator 0.5637669563293457
# train loss Generator 0.3217768669128418
# Epoch: 25
# train loss Discriminator 0.6060105562210083
# train loss Generator 0.4910408854484558
# Epoch: 25
# train loss Discriminator 0.6468340158462524
# train loss Generator 0.49089187383651733
# Epoch: 25
# train loss Discriminator 0.673805832862854
# train loss Generator 0.49089187383651733
# Epoch: 25
# train loss Discriminator 0.660653293132782
# train loss Generator 0.48351237177848816
# Epoch: 25
# train loss Discriminator 0.4788081645965576
# train loss Generator 0.610789954662323
# Epoch: 25
# train loss Discriminator 0.6564590930938721
# train loss Generator 0.39239823818206787
# Epoch: 25
# train loss Discriminator 0.6554216742515564
# train loss Generator 0.37505030632019043
# Epoch : 25 , MAE val:  0.880893269468351
# Epoch : 25 , RMSE val:  0.880893269468351
# Epoch : 25 , MAPE val:  -0.4897692087589574
# Epoch : 25 , AR val:  -0.03756783444312379
# Epoch: 26
# train loss Discriminator 0.5862839818000793
# train loss Generator 0.5353042483329773
# Epoch: 26
# train loss Discriminator 0.6857852339744568
# train loss Generator 0.5043885707855225
# Epoch: 26
# train loss Discriminator 0.6131523847579956
# train loss Generator 0.42837607860565186
# Epoch: 26
# train loss Discriminator 0.5264503359794617
# train loss Generator 0.41954922676086426
# Epoch: 26
# train loss Discriminator 0.5530719757080078
# train loss Generator 0.41954922676086426
# Epoch: 26
# train loss Discriminator 0.6644189953804016
# train loss Generator 0.4005582928657532
# Epoch: 26
# train loss Discriminator 0.5756169557571411
# train loss Generator 0.46664994955062866
# Epoch: 26
# train loss Discriminator 0.6895519495010376
# train loss Generator 0.4798092246055603
# Epoch: 26
# train loss Discriminator 0.637866735458374
# train loss Generator 0.33592045307159424
# Epoch: 26
# train loss Discriminator 0.5647373199462891
# train loss Generator 0.33592045307159424
# Epoch: 26
# train loss Discriminator 0.600878119468689
# train loss Generator 0.3299456238746643
# Epoch: 26
# train loss Discriminator 0.7774931788444519
# train loss Generator 0.29564809799194336
# Epoch: 26
# train loss Discriminator 0.6476022005081177
# train loss Generator 0.46223777532577515
# Epoch: 26
# train loss Discriminator 0.6546359062194824
# train loss Generator 0.4200667142868042
# Epoch: 26
# train loss Discriminator 0.7379242181777954
# train loss Generator 0.4200667142868042
# Epoch: 26
# train loss Discriminator 0.6777278780937195
# train loss Generator 0.49379879236221313
# Epoch: 26
# train loss Discriminator 0.6305848360061646
# train loss Generator 0.4076950252056122
# Epoch: 26
# train loss Discriminator 0.6906912326812744
# train loss Generator 0.3230629563331604
# Epoch: 26
# train loss Discriminator 0.6362618207931519
# train loss Generator 0.41318222880363464
# Epoch : 26 , MAE val:  0.878532306972499
# Epoch : 26 , RMSE val:  0.878532306972499
# Epoch : 26 , MAPE val:  -0.4991985495671406
# Epoch : 26 , AR val:  -0.03434869280703512
# Epoch: 27
# train loss Discriminator 0.6372319459915161
# train loss Generator 0.4220307469367981
# Epoch: 27
# train loss Discriminator 0.7556086778640747
# train loss Generator 0.38986217975616455
# Epoch: 27
# train loss Discriminator 0.5696504712104797
# train loss Generator 0.3665544390678406
# Epoch: 27
# train loss Discriminator 0.6204724311828613
# train loss Generator 0.5505549907684326
# Epoch: 27
# train loss Discriminator 0.6114554405212402
# train loss Generator 0.5505549907684326
# Epoch: 27
# train loss Discriminator 0.5829118490219116
# train loss Generator 0.5190375447273254
# Epoch: 27
# train loss Discriminator 0.6567773222923279
# train loss Generator 0.43120110034942627
# Epoch: 27
# train loss Discriminator 0.5850808620452881
# train loss Generator 0.4237380027770996
# Epoch: 27
# train loss Discriminator 0.7239834070205688
# train loss Generator 0.4510035514831543
# Epoch: 27
# train loss Discriminator 0.622077465057373
# train loss Generator 0.4510035514831543
# Epoch: 27
# train loss Discriminator 0.6667405366897583
# train loss Generator 0.4021713435649872
# Epoch: 27
# train loss Discriminator 0.5592686533927917
# train loss Generator 0.6431472301483154
# Epoch: 27
# train loss Discriminator 0.6355329751968384
# train loss Generator 0.3671829104423523
# Epoch: 27
# train loss Discriminator 0.7309766411781311
# train loss Generator 0.5169311761856079
# Epoch: 27
# train loss Discriminator 0.6652829051017761
# train loss Generator 0.5169311761856079
# Epoch: 27
# train loss Discriminator 0.4922550320625305
# train loss Generator 0.4258986711502075
# Epoch: 27
# train loss Discriminator 0.6107110381126404
# train loss Generator 0.40427085757255554
# Epoch: 27
# train loss Discriminator 0.5554714202880859
# train loss Generator 0.4263046979904175
# Epoch: 27
# train loss Discriminator 0.6059480905532837
# train loss Generator 0.32462364435195923
# Epoch : 27 , MAE val:  0.8774536085630158
# Epoch : 27 , RMSE val:  0.8774536085630158
# Epoch : 27 , MAPE val:  -0.4973859025963715
# Epoch : 27 , AR val:  -0.03936234718021735
# Epoch: 28
# train loss Discriminator 0.6622309684753418
# train loss Generator 0.3162091076374054
# Epoch: 28
# train loss Discriminator 0.5037490129470825
# train loss Generator 0.5407186150550842
# Epoch: 28
# train loss Discriminator 0.7233433127403259
# train loss Generator 0.38794660568237305
# Epoch: 28
# train loss Discriminator 0.7046881914138794
# train loss Generator 0.47648704051971436
# Epoch: 28
# train loss Discriminator 0.5176089406013489
# train loss Generator 0.47648704051971436
# Epoch: 28
# train loss Discriminator 0.6550649404525757
# train loss Generator 0.38447967171669006
# Epoch: 28
# train loss Discriminator 0.6282235980033875
# train loss Generator 0.4211375415325165
# Epoch: 28
# train loss Discriminator 0.6285476088523865
# train loss Generator 0.27295058965682983
# Epoch: 28
# train loss Discriminator 0.6152309775352478
# train loss Generator 0.4575861692428589
# Epoch: 28
# train loss Discriminator 0.605889081954956
# train loss Generator 0.4575861692428589
# Epoch: 28
# train loss Discriminator 0.6147785186767578
# train loss Generator 0.4717903137207031
# Epoch: 28
# train loss Discriminator 0.5185886025428772
# train loss Generator 0.4414495527744293
# Epoch: 28
# train loss Discriminator 0.5898897647857666
# train loss Generator 0.38477084040641785
# Epoch: 28
# train loss Discriminator 0.6831755042076111
# train loss Generator 0.48271408677101135
# Epoch: 28
# train loss Discriminator 0.6286212801933289
# train loss Generator 0.48271408677101135
# Epoch: 28
# train loss Discriminator 0.6184816956520081
# train loss Generator 0.4641328454017639
# Epoch: 28
# train loss Discriminator 0.7055484652519226
# train loss Generator 0.5907443761825562
# Epoch: 28
# train loss Discriminator 0.5148943066596985
# train loss Generator 0.42762601375579834
# Epoch: 28
# train loss Discriminator 0.6390737891197205
# train loss Generator 0.4941931664943695
# Epoch : 28 , MAE val:  0.8764022573646634
# Epoch : 28 , RMSE val:  0.8764022573646634
# Epoch : 28 , MAPE val:  -0.49985864947276903
# Epoch : 28 , AR val:  -0.03999252015961816
# Epoch: 29
# train loss Discriminator 0.6898061633110046
# train loss Generator 0.5099814534187317
# Epoch: 29
# train loss Discriminator 0.5844894051551819
# train loss Generator 0.40717601776123047
# Epoch: 29
# train loss Discriminator 0.639365553855896
# train loss Generator 0.36771953105926514
# Epoch: 29
# train loss Discriminator 0.637475311756134
# train loss Generator 0.341251015663147
# Epoch: 29
# train loss Discriminator 0.590735673904419
# train loss Generator 0.341251015663147
# Epoch: 29
# train loss Discriminator 0.6460323929786682
# train loss Generator 0.392831027507782
# Epoch: 29
# train loss Discriminator 0.565716564655304
# train loss Generator 0.46707385778427124
# Epoch: 29
# train loss Discriminator 0.5782500505447388
# train loss Generator 0.38423824310302734
# Epoch: 29
# train loss Discriminator 0.5913144946098328
# train loss Generator 0.4333559274673462
# Epoch: 29
# train loss Discriminator 0.7006438970565796
# train loss Generator 0.4333559274673462
# Epoch: 29
# train loss Discriminator 0.5338402390480042
# train loss Generator 0.552182674407959
# Epoch: 29
# train loss Discriminator 0.7193116545677185
# train loss Generator 0.4810889661312103
# Epoch: 29
# train loss Discriminator 0.6754022240638733
# train loss Generator 0.3543977737426758
# Epoch: 29
# train loss Discriminator 0.5938061475753784
# train loss Generator 0.36939263343811035
# Epoch: 29
# train loss Discriminator 0.4647817015647888
# train loss Generator 0.36939263343811035
# Epoch: 29
# train loss Discriminator 0.7188065052032471
# train loss Generator 0.3240656554698944
# Epoch: 29
# train loss Discriminator 0.7947288751602173
# train loss Generator 0.3396661877632141
# Epoch: 29
# train loss Discriminator 0.7145618200302124
# train loss Generator 0.39378389716148376
# Epoch: 29
# train loss Discriminator 0.6281259655952454
# train loss Generator 0.525648832321167
# Epoch : 29 , MAE val:  0.8748362383434087
# Epoch : 29 , RMSE val:  0.8748362383434087
# Epoch : 29 , MAPE val:  -0.5114508018232847
# Epoch : 29 , AR val:  -0.03691203120278183
# Epoch: 30
# train loss Discriminator 0.6838278770446777
# train loss Generator 0.3757614195346832
# Epoch: 30
# train loss Discriminator 0.45541077852249146
# train loss Generator 0.5078045129776001
# Epoch: 30
# train loss Discriminator 0.6576136946678162
# train loss Generator 0.500957727432251
# Epoch: 30
# train loss Discriminator 0.5695538520812988
# train loss Generator 0.4920862317085266
# Epoch: 30
# train loss Discriminator 0.7053428888320923
# train loss Generator 0.4920862317085266
# Epoch: 30
# train loss Discriminator 0.6477993726730347
# train loss Generator 0.469057559967041
# Epoch: 30
# train loss Discriminator 0.6223881244659424
# train loss Generator 0.34468358755111694
# Epoch: 30
# train loss Discriminator 0.6708260774612427
# train loss Generator 0.4433240294456482
# Epoch: 30
# train loss Discriminator 0.6355060338973999
# train loss Generator 0.4318927824497223
# Epoch: 30
# train loss Discriminator 0.6374516487121582
# train loss Generator 0.4318927824497223
# Epoch: 30
# train loss Discriminator 0.6016937494277954
# train loss Generator 0.5166935324668884
# Epoch: 30
# train loss Discriminator 0.5176281929016113
# train loss Generator 0.45952439308166504
# Epoch: 30
# train loss Discriminator 0.6642639636993408
# train loss Generator 0.3681069016456604
# Epoch: 30
# train loss Discriminator 0.5139814019203186
# train loss Generator 0.4594009518623352
# Epoch: 30
# train loss Discriminator 0.6468590497970581
# train loss Generator 0.4594009518623352
# Epoch: 30
# train loss Discriminator 0.5542579889297485
# train loss Generator 0.5356498956680298
# Epoch: 30
# train loss Discriminator 0.6223320364952087
# train loss Generator 0.42324262857437134
# Epoch: 30
# train loss Discriminator 0.6911410093307495
# train loss Generator 0.4898231029510498
# Epoch: 30
# train loss Discriminator 0.5385618805885315
# train loss Generator 0.38994789123535156
# Epoch : 30 , MAE val:  0.8729084290234946
# Epoch : 30 , RMSE val:  0.8729084290234946
# Epoch : 30 , MAPE val:  -0.5068278373641845
# Epoch : 30 , AR val:  -0.033263684497621605
# Epoch: 31
# train loss Discriminator 0.5711162686347961
# train loss Generator 0.508501410484314
# Epoch: 31
# train loss Discriminator 0.6195954084396362
# train loss Generator 0.3177863359451294
# Epoch: 31
# train loss Discriminator 0.611487865447998
# train loss Generator 0.42051175236701965
# Epoch: 31
# train loss Discriminator 0.5931040644645691
# train loss Generator 0.4510374367237091
# Epoch: 31
# train loss Discriminator 0.6132352352142334
# train loss Generator 0.4510374367237091
# Epoch: 31
# train loss Discriminator 0.5974414348602295
# train loss Generator 0.4436935782432556
# Epoch: 31
# train loss Discriminator 0.6201443672180176
# train loss Generator 0.4945584535598755
# Epoch: 31
# train loss Discriminator 0.5920357704162598
# train loss Generator 0.47537004947662354
# Epoch: 31
# train loss Discriminator 0.5388149619102478
# train loss Generator 0.3896191418170929
# Epoch: 31
# train loss Discriminator 0.6201751232147217
# train loss Generator 0.3896191418170929
# Epoch: 31
# train loss Discriminator 0.5880414247512817
# train loss Generator 0.3733322024345398
# Epoch: 31
# train loss Discriminator 0.6749467849731445
# train loss Generator 0.36964255571365356
# Epoch: 31
# train loss Discriminator 0.5779184699058533
# train loss Generator 0.4068755507469177
# Epoch: 31
# train loss Discriminator 0.5745106935501099
# train loss Generator 0.43659618496894836
# Epoch: 31
# train loss Discriminator 0.6004933714866638
# train loss Generator 0.43659618496894836
# Epoch: 31
# train loss Discriminator 0.6459790468215942
# train loss Generator 0.4278106689453125
# Epoch: 31
# train loss Discriminator 0.6401784420013428
# train loss Generator 0.4032233953475952
# Epoch: 31
# train loss Discriminator 0.6604286432266235
# train loss Generator 0.2545113265514374
# Epoch: 31
# train loss Discriminator 0.5871713757514954
# train loss Generator 0.5824677348136902
# Epoch : 31 , MAE val:  0.8706247320552741
# Epoch : 31 , RMSE val:  0.8706247320552741
# Epoch : 31 , MAPE val:  -0.5166597354603946
# Epoch : 31 , AR val:  -0.032569660665256996
# Epoch: 32
# train loss Discriminator 0.6836720108985901
# train loss Generator 0.3959382176399231
# Epoch: 32
# train loss Discriminator 0.5397424101829529
# train loss Generator 0.4663582444190979
# Epoch: 32
# train loss Discriminator 0.6035423278808594
# train loss Generator 0.4595303535461426
# Epoch: 32
# train loss Discriminator 0.5933369994163513
# train loss Generator 0.4508991837501526
# Epoch: 32
# train loss Discriminator 0.5195850133895874
# train loss Generator 0.4508991837501526
# Epoch: 32
# train loss Discriminator 0.6347823143005371
# train loss Generator 0.46698570251464844
# Epoch: 32
# train loss Discriminator 0.5106558203697205
# train loss Generator 0.5254490375518799
# Epoch: 32
# train loss Discriminator 0.627373993396759
# train loss Generator 0.31836581230163574
# Epoch: 32
# train loss Discriminator 0.6359217762947083
# train loss Generator 0.4537791609764099
# Epoch: 32
# train loss Discriminator 0.5891873836517334
# train loss Generator 0.4537791609764099
# Epoch: 32
# train loss Discriminator 0.6895205974578857
# train loss Generator 0.33180534839630127
# Epoch: 32
# train loss Discriminator 0.5173255205154419
# train loss Generator 0.3962239623069763
# Epoch: 32
# train loss Discriminator 0.6508711576461792
# train loss Generator 0.40799885988235474
# Epoch: 32
# train loss Discriminator 0.63482666015625
# train loss Generator 0.376417875289917
# Epoch: 32
# train loss Discriminator 0.6044873595237732
# train loss Generator 0.376417875289917
# Epoch: 32
# train loss Discriminator 0.5362736582756042
# train loss Generator 0.5538812279701233
# Epoch: 32
# train loss Discriminator 0.5473101139068604
# train loss Generator 0.5291483402252197
# Epoch: 32
# train loss Discriminator 0.5460949540138245
# train loss Generator 0.430926114320755
# Epoch: 32
# train loss Discriminator 0.6966705322265625
# train loss Generator 0.37776368856430054
# Epoch : 32 , MAE val:  0.8692285147782667
# Epoch : 32 , RMSE val:  0.8692285147782667
# Epoch : 32 , MAPE val:  -0.5164602823576476
# Epoch : 32 , AR val:  -0.0339508492065487
# Epoch: 33
# train loss Discriminator 0.6499025821685791
# train loss Generator 0.4275970458984375
# Epoch: 33
# train loss Discriminator 0.5328134298324585
# train loss Generator 0.5183244347572327
# Epoch: 33
# train loss Discriminator 0.598471999168396
# train loss Generator 0.3969137966632843
# Epoch: 33
# train loss Discriminator 0.5804271101951599
# train loss Generator 0.4040682315826416
# Epoch: 33
# train loss Discriminator 0.6491973996162415
# train loss Generator 0.4040682315826416
# Epoch: 33
# train loss Discriminator 0.52483069896698
# train loss Generator 0.5454080104827881
# Epoch: 33
# train loss Discriminator 0.4902395009994507
# train loss Generator 0.4743412435054779
# Epoch: 33
# train loss Discriminator 0.6200918555259705
# train loss Generator 0.46253806352615356
# Epoch: 33
# train loss Discriminator 0.6553751230239868
# train loss Generator 0.41639822721481323
# Epoch: 33
# train loss Discriminator 0.5833337903022766
# train loss Generator 0.41639822721481323
# Epoch: 33
# train loss Discriminator 0.6268784999847412
# train loss Generator 0.4057202935218811
# Epoch: 33
# train loss Discriminator 0.608954668045044
# train loss Generator 0.34774357080459595
# Epoch: 33
# train loss Discriminator 0.6668294668197632
# train loss Generator 0.42552030086517334
# Epoch: 33
# train loss Discriminator 0.5646088123321533
# train loss Generator 0.4470747113227844
# Epoch: 33
# train loss Discriminator 0.582791268825531
# train loss Generator 0.4470747113227844
# Epoch: 33
# train loss Discriminator 0.5229238271713257
# train loss Generator 0.341960608959198
# Epoch: 33
# train loss Discriminator 0.60894775390625
# train loss Generator 0.37741559743881226
# Epoch: 33
# train loss Discriminator 0.6442508697509766
# train loss Generator 0.5311734676361084
# Epoch: 33
# train loss Discriminator 0.6827691793441772
# train loss Generator 0.3096386194229126
# Epoch : 33 , MAE val:  0.8683200455753874
# Epoch : 33 , RMSE val:  0.8683200455753874
# Epoch : 33 , MAPE val:  -0.5212311465762332
# Epoch : 33 , AR val:  -0.02895130460039735
# Epoch: 34
# train loss Discriminator 0.5694804191589355
# train loss Generator 0.39281731843948364
# Epoch: 34
# train loss Discriminator 0.6542664170265198
# train loss Generator 0.3449845314025879
# Epoch: 34
# train loss Discriminator 0.7064250111579895
# train loss Generator 0.44566676020622253
# Epoch: 34
# train loss Discriminator 0.6696528196334839
# train loss Generator 0.3184939920902252
# Epoch: 34
# train loss Discriminator 0.5860510468482971
# train loss Generator 0.3184939920902252
# Epoch: 34
# train loss Discriminator 0.5543388724327087
# train loss Generator 0.4744241535663605
# Epoch: 34
# train loss Discriminator 0.6601758599281311
# train loss Generator 0.4231811761856079
# Epoch: 34
# train loss Discriminator 0.608981728553772
# train loss Generator 0.39052513241767883
# Epoch: 34
# train loss Discriminator 0.639132022857666
# train loss Generator 0.5612573623657227
# Epoch: 34
# train loss Discriminator 0.4972888231277466
# train loss Generator 0.5612573623657227
# Epoch: 34
# train loss Discriminator 0.6042556166648865
# train loss Generator 0.4357527792453766
# Epoch: 34
# train loss Discriminator 0.5936577320098877
# train loss Generator 0.37588727474212646
# Epoch: 34
# train loss Discriminator 0.7381089925765991
# train loss Generator 0.3040039539337158
# Epoch: 34
# train loss Discriminator 0.6803538799285889
# train loss Generator 0.46006113290786743
# Epoch: 34
# train loss Discriminator 0.5446763038635254
# train loss Generator 0.46006113290786743
# Epoch: 34
# train loss Discriminator 0.6158949732780457
# train loss Generator 0.4502875804901123
# Epoch: 34
# train loss Discriminator 0.5555813312530518
# train loss Generator 0.4672289788722992
# Epoch: 34
# train loss Discriminator 0.657136082649231
# train loss Generator 0.3803631067276001
# Epoch: 34
# train loss Discriminator 0.6087667346000671
# train loss Generator 0.37269604206085205
# Epoch : 34 , MAE val:  0.8669143219604472
# Epoch : 34 , RMSE val:  0.8669143219604472
# Epoch : 34 , MAPE val:  -0.5213846968584939
# Epoch : 34 , AR val:  -0.027098029958861264
# Epoch: 35
# train loss Discriminator 0.5537278652191162
# train loss Generator 0.3592807948589325
# Epoch: 35
# train loss Discriminator 0.6129871606826782
# train loss Generator 0.39008209109306335
# Epoch: 35
# train loss Discriminator 0.5899507403373718
# train loss Generator 0.4046160876750946
# Epoch: 35
# train loss Discriminator 0.5244290828704834
# train loss Generator 0.4365500211715698
# Epoch: 35
# train loss Discriminator 0.4842410087585449
# train loss Generator 0.4365500211715698
# Epoch: 35
# train loss Discriminator 0.4672445058822632
# train loss Generator 0.4955947697162628
# Epoch: 35
# train loss Discriminator 0.4944837987422943
# train loss Generator 0.42432907223701477
# Epoch: 35
# train loss Discriminator 0.5495630502700806
# train loss Generator 0.5012151002883911
# Epoch: 35
# train loss Discriminator 0.5089830756187439
# train loss Generator 0.5362206697463989
# Epoch: 35
# train loss Discriminator 0.6680253744125366
# train loss Generator 0.5362206697463989
# Epoch: 35
# train loss Discriminator 0.8428457379341125
# train loss Generator 0.29389792680740356
# Epoch: 35
# train loss Discriminator 0.6627181768417358
# train loss Generator 0.31212109327316284
# Epoch: 35
# train loss Discriminator 0.5554129481315613
# train loss Generator 0.3760245740413666
# Epoch: 35
# train loss Discriminator 0.43548524379730225
# train loss Generator 0.48659151792526245
# Epoch: 35
# train loss Discriminator 0.5597648620605469
# train loss Generator 0.48659151792526245
# Epoch: 35
# train loss Discriminator 0.5281227827072144
# train loss Generator 0.46062421798706055
# Epoch: 35
# train loss Discriminator 0.5546050071716309
# train loss Generator 0.4982438385486603
# Epoch: 35
# train loss Discriminator 0.5826300978660583
# train loss Generator 0.47097691893577576
# Epoch: 35
# train loss Discriminator 0.6550742387771606
# train loss Generator 0.3939513564109802
# Epoch : 35 , MAE val:  0.8651486641167194
# Epoch : 35 , RMSE val:  0.8651486641167194
# Epoch : 35 , MAPE val:  -0.5251419181942492
# Epoch : 35 , AR val:  -0.024825249063987174
# Epoch: 36
# train loss Discriminator 0.6698974967002869
# train loss Generator 0.3262265920639038
# Epoch: 36
# train loss Discriminator 0.4836723208427429
# train loss Generator 0.42832422256469727
# Epoch: 36
# train loss Discriminator 0.5503926873207092
# train loss Generator 0.3799259066581726
# Epoch: 36
# train loss Discriminator 0.5168704986572266
# train loss Generator 0.35522595047950745
# Epoch: 36
# train loss Discriminator 0.7260292768478394
# train loss Generator 0.35522595047950745
# Epoch: 36
# train loss Discriminator 0.5497676730155945
# train loss Generator 0.5151227712631226
# Epoch: 36
# train loss Discriminator 0.5711972117424011
# train loss Generator 0.34455984830856323
# Epoch: 36
# train loss Discriminator 0.5950008630752563
# train loss Generator 0.5409466028213501
# Epoch: 36
# train loss Discriminator 0.7542412281036377
# train loss Generator 0.32182908058166504
# Epoch: 36
# train loss Discriminator 0.544094443321228
# train loss Generator 0.32182908058166504
# Epoch: 36
# train loss Discriminator 0.501789927482605
# train loss Generator 0.48080238699913025
# Epoch: 36
# train loss Discriminator 0.5400465726852417
# train loss Generator 0.5371279716491699
# Epoch: 36
# train loss Discriminator 0.5664810538291931
# train loss Generator 0.36774423718452454
# Epoch: 36
# train loss Discriminator 0.6028732657432556
# train loss Generator 0.4974965453147888
# Epoch: 36
# train loss Discriminator 0.544897198677063
# train loss Generator 0.4974965453147888
# Epoch: 36
# train loss Discriminator 0.5978807210922241
# train loss Generator 0.37701189517974854
# Epoch: 36
# train loss Discriminator 0.6002269387245178
# train loss Generator 0.4466037452220917
# Epoch: 36
# train loss Discriminator 0.5081979036331177
# train loss Generator 0.5156495571136475
# Epoch: 36
# train loss Discriminator 0.528541088104248
# train loss Generator 0.4705490171909332
# Epoch : 36 , MAE val:  0.8646334138866935
# Epoch : 36 , RMSE val:  0.8646334138866935
# Epoch : 36 , MAPE val:  -0.5269793069214189
# Epoch : 36 , AR val:  -0.024330596310852364
# Epoch: 37
# train loss Discriminator 0.6461724042892456
# train loss Generator 0.4319913685321808
# Epoch: 37
# train loss Discriminator 0.6266793012619019
# train loss Generator 0.4437105655670166
# Epoch: 37
# train loss Discriminator 0.4732901155948639
# train loss Generator 0.5575675368309021
# Epoch: 37
# train loss Discriminator 0.5551374554634094
# train loss Generator 0.4674181640148163
# Epoch: 37
# train loss Discriminator 0.5832453966140747
# train loss Generator 0.4674181640148163
# Epoch: 37
# train loss Discriminator 0.6775609254837036
# train loss Generator 0.3769983947277069
# Epoch: 37
# train loss Discriminator 0.48770737648010254
# train loss Generator 0.3869067132472992
# Epoch: 37
# train loss Discriminator 0.604785144329071
# train loss Generator 0.3903352618217468
# Epoch: 37
# train loss Discriminator 0.5341711044311523
# train loss Generator 0.45797035098075867
# Epoch: 37
# train loss Discriminator 0.5416097044944763
# train loss Generator 0.45797035098075867
# Epoch: 37
# train loss Discriminator 0.6691968441009521
# train loss Generator 0.35437673330307007
# Epoch: 37
# train loss Discriminator 0.4882567226886749
# train loss Generator 0.36760252714157104
# Epoch: 37
# train loss Discriminator 0.5513445138931274
# train loss Generator 0.46713873744010925
# Epoch: 37
# train loss Discriminator 0.637066125869751
# train loss Generator 0.48899927735328674
# Epoch: 37
# train loss Discriminator 0.6299747228622437
# train loss Generator 0.48899927735328674
# Epoch: 37
# train loss Discriminator 0.5143450498580933
# train loss Generator 0.43533772230148315
# Epoch: 37
# train loss Discriminator 0.5956864356994629
# train loss Generator 0.47638335824012756
# Epoch: 37
# train loss Discriminator 0.6554221510887146
# train loss Generator 0.2867538332939148
# Epoch: 37
# train loss Discriminator 0.6950129866600037
# train loss Generator 0.4480440616607666
# Epoch : 37 , MAE val:  0.8638964037326886
# Epoch : 37 , RMSE val:  0.8638964037326886
# Epoch : 37 , MAPE val:  -0.5353714680572258
# Epoch : 37 , AR val:  -0.027844921534625724
# Epoch: 38
# train loss Discriminator 0.5553280115127563
# train loss Generator 0.45009952783584595
# Epoch: 38
# train loss Discriminator 0.6922234296798706
# train loss Generator 0.4002096354961395
# Epoch: 38
# train loss Discriminator 0.7154908180236816
# train loss Generator 0.4233476221561432
# Epoch: 38
# train loss Discriminator 0.6399299502372742
# train loss Generator 0.2979641556739807
# Epoch: 38
# train loss Discriminator 0.653906524181366
# train loss Generator 0.2979641556739807
# Epoch: 38
# train loss Discriminator 0.5826573967933655
# train loss Generator 0.3969324231147766
# Epoch: 38
# train loss Discriminator 0.5778671503067017
# train loss Generator 0.39099255204200745
# Epoch: 38
# train loss Discriminator 0.6761038303375244
# train loss Generator 0.3996196389198303
# Epoch: 38
# train loss Discriminator 0.5694013833999634
# train loss Generator 0.5028731822967529
# Epoch: 38
# train loss Discriminator 0.46571481227874756
# train loss Generator 0.5028731822967529
# Epoch: 38
# train loss Discriminator 0.5564084649085999
# train loss Generator 0.5677072405815125
# Epoch: 38
# train loss Discriminator 0.6456795930862427
# train loss Generator 0.31164005398750305
# Epoch: 38
# train loss Discriminator 0.5390653610229492
# train loss Generator 0.3670920729637146
# Epoch: 38
# train loss Discriminator 0.5116406679153442
# train loss Generator 0.5308152437210083
# Epoch: 38
# train loss Discriminator 0.550502359867096
# train loss Generator 0.5308152437210083
# Epoch: 38
# train loss Discriminator 0.8078335523605347
# train loss Generator 0.4408941864967346
# Epoch: 38
# train loss Discriminator 0.6098789572715759
# train loss Generator 0.31735968589782715
# Epoch: 38
# train loss Discriminator 0.6462042927742004
# train loss Generator 0.3948603570461273
# Epoch: 38
# train loss Discriminator 0.46037107706069946
# train loss Generator 0.41905802488327026
# Epoch : 38 , MAE val:  0.8638365932285114
# Epoch : 38 , RMSE val:  0.8638365932285114
# Epoch : 38 , MAPE val:  -0.5325837886437101
# Epoch : 38 , AR val:  -0.029470540140264567
# Epoch: 39
# train loss Discriminator 0.613731861114502
# train loss Generator 0.4424716532230377
# Epoch: 39
# train loss Discriminator 0.5345957279205322
# train loss Generator 0.47143515944480896
# Epoch: 39
# train loss Discriminator 0.6548558473587036
# train loss Generator 0.3755092918872833
# Epoch: 39
# train loss Discriminator 0.6666905879974365
# train loss Generator 0.39481881260871887
# Epoch: 39
# train loss Discriminator 0.6085673570632935
# train loss Generator 0.39481881260871887
# Epoch: 39
# train loss Discriminator 0.7020819187164307
# train loss Generator 0.4524732530117035
# Epoch: 39
# train loss Discriminator 0.6219631433486938
# train loss Generator 0.47013723850250244
# Epoch: 39
# train loss Discriminator 0.5637902021408081
# train loss Generator 0.4407608211040497
# Epoch: 39
# train loss Discriminator 0.6548128128051758
# train loss Generator 0.3683973550796509
# Epoch: 39
# train loss Discriminator 0.6065027117729187
# train loss Generator 0.3683973550796509
# Epoch: 39
# train loss Discriminator 0.7262071371078491
# train loss Generator 0.3556123375892639
# Epoch: 39
# train loss Discriminator 0.6390931010246277
# train loss Generator 0.35997655987739563
# Epoch: 39
# train loss Discriminator 0.5254870057106018
# train loss Generator 0.4247690439224243
# Epoch: 39
# train loss Discriminator 0.5964741706848145
# train loss Generator 0.4288601577281952
# Epoch: 39
# train loss Discriminator 0.534705400466919
# train loss Generator 0.4288601577281952
# Epoch: 39
# train loss Discriminator 0.4491177201271057
# train loss Generator 0.501274585723877
# Epoch: 39
# train loss Discriminator 0.542949378490448
# train loss Generator 0.4814583659172058
# Epoch: 39
# train loss Discriminator 0.5580102801322937
# train loss Generator 0.3921777009963989
# Epoch: 39
# train loss Discriminator 0.45779162645339966
# train loss Generator 0.4907727837562561
# Epoch : 39 , MAE val:  0.8625780564949925
# Epoch : 39 , RMSE val:  0.8625780564949925
# Epoch : 39 , MAPE val:  -0.534579047523579
# Epoch : 39 , AR val:  -0.03039408395528311
# Epoch: 40
# train loss Discriminator 0.6504849195480347
# train loss Generator 0.47920510172843933
# Epoch: 40
# train loss Discriminator 0.6797230839729309
# train loss Generator 0.23467129468917847
# Epoch: 40
# train loss Discriminator 0.5066477060317993
# train loss Generator 0.5131101012229919
# Epoch: 40
# train loss Discriminator 0.5942294001579285
# train loss Generator 0.5696630477905273
# Epoch: 40
# train loss Discriminator 0.6250737309455872
# train loss Generator 0.5696630477905273
# Epoch: 40
# train loss Discriminator 0.6026379466056824
# train loss Generator 0.42289671301841736
# Epoch: 40
# train loss Discriminator 0.5688159465789795
# train loss Generator 0.43273621797561646
# Epoch: 40
# train loss Discriminator 0.5117445588111877
# train loss Generator 0.3217998445034027
# Epoch: 40
# train loss Discriminator 0.6197575926780701
# train loss Generator 0.45175421237945557
# Epoch: 40
# train loss Discriminator 0.5409743785858154
# train loss Generator 0.45175421237945557
# Epoch: 40
# train loss Discriminator 0.6080305576324463
# train loss Generator 0.46790584921836853
# Epoch: 40
# train loss Discriminator 0.5824458003044128
# train loss Generator 0.4102447032928467
# Epoch: 40
# train loss Discriminator 0.6676488518714905
# train loss Generator 0.43815189599990845
# Epoch: 40
# train loss Discriminator 0.5761237740516663
# train loss Generator 0.45610928535461426
# Epoch: 40
# train loss Discriminator 0.5972113013267517
# train loss Generator 0.45610928535461426
# Epoch: 40
# train loss Discriminator 0.5322521924972534
# train loss Generator 0.4099082052707672
# Epoch: 40
# train loss Discriminator 0.602899432182312
# train loss Generator 0.34344935417175293
# Epoch: 40
# train loss Discriminator 0.5302876830101013
# train loss Generator 0.37877464294433594
# Epoch: 40
# train loss Discriminator 0.47976523637771606
# train loss Generator 0.4001154899597168
# Epoch : 40 , MAE val:  0.8618399489131805
# Epoch : 40 , RMSE val:  0.8618399489131805
# Epoch : 40 , MAPE val:  -0.5440869090819549
# Epoch : 40 , AR val:  -0.02564993111384438
# Epoch: 41
# train loss Discriminator 0.5417110323905945
# train loss Generator 0.46739619970321655
# Epoch: 41
# train loss Discriminator 0.6336843967437744
# train loss Generator 0.4604811668395996
# Epoch: 41
# train loss Discriminator 0.5827423334121704
# train loss Generator 0.36428457498550415
# Epoch: 41
# train loss Discriminator 0.477069616317749
# train loss Generator 0.5067065358161926
# Epoch: 41
# train loss Discriminator 0.6026619672775269
# train loss Generator 0.5067065358161926
# Epoch: 41
# train loss Discriminator 0.6136044263839722
# train loss Generator 0.38470029830932617
# Epoch: 41
# train loss Discriminator 0.6103447079658508
# train loss Generator 0.48679307103157043
# Epoch: 41
# train loss Discriminator 0.529001772403717
# train loss Generator 0.39964550733566284
# Epoch: 41
# train loss Discriminator 0.6452463865280151
# train loss Generator 0.42763015627861023
# Epoch: 41
# train loss Discriminator 0.6741430163383484
# train loss Generator 0.42763015627861023
# Epoch: 41
# train loss Discriminator 0.6255133152008057
# train loss Generator 0.4660133719444275
# Epoch: 41
# train loss Discriminator 0.6323415040969849
# train loss Generator 0.427254319190979
# Epoch: 41
# train loss Discriminator 0.6064205169677734
# train loss Generator 0.5591140985488892
# Epoch: 41
# train loss Discriminator 0.5750589370727539
# train loss Generator 0.3705674409866333
# Epoch: 41
# train loss Discriminator 0.8377509713172913
# train loss Generator 0.3705674409866333
# Epoch: 41
# train loss Discriminator 0.5963741540908813
# train loss Generator 0.30510976910591125
# Epoch: 41
# train loss Discriminator 0.4340671896934509
# train loss Generator 0.5043639540672302
# Epoch: 41
# train loss Discriminator 0.5076677799224854
# train loss Generator 0.4381091296672821
# Epoch: 41
# train loss Discriminator 0.6429116725921631
# train loss Generator 0.49014872312545776
# Epoch : 41 , MAE val:  0.8613122058486132
# Epoch : 41 , RMSE val:  0.8613122058486132
# Epoch : 41 , MAPE val:  -0.539490541045491
# Epoch : 41 , AR val:  -0.023704520006262955
# Epoch: 42
# train loss Discriminator 0.5003702640533447
# train loss Generator 0.4283623993396759
# Epoch: 42
# train loss Discriminator 0.5666975975036621
# train loss Generator 0.4954635500907898
# Epoch: 42
# train loss Discriminator 0.6317993402481079
# train loss Generator 0.35982370376586914
# Epoch: 42
# train loss Discriminator 0.6061317920684814
# train loss Generator 0.4048454463481903
# Epoch: 42
# train loss Discriminator 0.5955945253372192
# train loss Generator 0.4048454463481903
# Epoch: 42
# train loss Discriminator 0.6170634627342224
# train loss Generator 0.3763055205345154
# Epoch: 42
# train loss Discriminator 0.5922147035598755
# train loss Generator 0.4267486333847046
# Epoch: 42
# train loss Discriminator 0.613881528377533
# train loss Generator 0.2574882209300995
# Epoch: 42
# train loss Discriminator 0.5846573114395142
# train loss Generator 0.45513665676116943
# Epoch: 42
# train loss Discriminator 0.6473584175109863
# ...
# Epoch: 91
# train loss Discriminator 0.4401889443397522
# train loss Generator 0.36375701427459717
# Epoch : 91 , MAE val:  0.8399142331716821
# Epoch : 91 , RMSE val:  0.8399142331716821
# Epoch : 91 , MAPE val:  -0.5386113054129554
# Epoch : 91 , AR val:  -0.019209500374510906
# Epoch: 92
# train loss Discriminator 0.5199804306030273
# train loss Generator 0.440711110830307
# Epoch: 92
# train loss Discriminator 0.48997053503990173
# train loss Generator 0.4459470510482788
# Epoch: 92
# train loss Discriminator 0.5888499021530151
# train loss Generator 0.4490361511707306
# Epoch: 92
# train loss Discriminator 0.616365373134613
# train loss Generator 0.274882435798645
# Epoch: 92
# train loss Discriminator 0.5618616342544556
# train loss Generator 0.274882435798645
# Epoch: 92
# train loss Discriminator 0.47445616126060486
# train loss Generator 0.36582550406455994
# Epoch: 92
# train loss Discriminator 0.5407590866088867
# train loss Generator 0.37823984026908875
# Epoch: 92
# train loss Discriminator 0.605654239654541
# train loss Generator 0.42010170221328735
# Epoch: 92
# train loss Discriminator 0.49060338735580444
# train loss Generator 0.444526344537735
# Epoch: 92
# train loss Discriminator 0.511972188949585
# train loss Generator 0.444526344537735
# Epoch: 92
# train loss Discriminator 0.5717505216598511
# train loss Generator 0.3456728160381317
# Epoch: 92
# train loss Discriminator 0.6245667934417725
# train loss Generator 0.39476478099823
# Epoch: 92
# train loss Discriminator 0.5183145999908447
# train loss Generator 0.4227368235588074
# Epoch: 92
# train loss Discriminator 0.5231146812438965
# train loss Generator 0.4153335690498352
# Epoch: 92
# train loss Discriminator 0.6247642040252686
# train loss Generator 0.4153335690498352
# Epoch: 92
# train loss Discriminator 0.5943725109100342
# train loss Generator 0.3311067521572113
# Epoch: 92
# train loss Discriminator 0.48913270235061646
# train loss Generator 0.40761351585388184
# Epoch: 92
# train loss Discriminator 0.5574550628662109
# train loss Generator 0.40070509910583496
# Epoch: 92
# train loss Discriminator 0.5249302387237549
# train loss Generator 0.3241058588027954
# Epoch : 92 , MAE val:  0.8387971104815939
# Epoch : 92 , RMSE val:  0.8387971104815939
# Epoch : 92 , MAPE val:  -0.5577685872828098
# Epoch : 92 , AR val:  -0.02159892425469841
# Epoch: 93
# train loss Discriminator 0.5181190967559814
# train loss Generator 0.40337231755256653
# Epoch: 93
# train loss Discriminator 0.608953058719635
# train loss Generator 0.4187489449977875
# Epoch: 93
# train loss Discriminator 0.5145310759544373
# train loss Generator 0.5812419652938843
# Epoch: 93
# train loss Discriminator 0.5966354012489319
# train loss Generator 0.26250338554382324
# Epoch: 93
# train loss Discriminator 0.5947170257568359
# train loss Generator 0.26250338554382324
# Epoch: 93
# train loss Discriminator 0.5199304819107056
# train loss Generator 0.36064833402633667
# Epoch: 93
# train loss Discriminator 0.4793364405632019
# train loss Generator 0.25930267572402954
# Epoch: 93
# train loss Discriminator 0.46259796619415283
# train loss Generator 0.44412761926651
# Epoch: 93
# train loss Discriminator 0.5996759533882141
# train loss Generator 0.4400388300418854
# Epoch: 93
# train loss Discriminator 0.5162028074264526
# train loss Generator 0.4400388300418854
# Epoch: 93
# train loss Discriminator 0.6266079545021057
# train loss Generator 0.4007579982280731
# Epoch: 93
# train loss Discriminator 0.4978353977203369
# train loss Generator 0.33875900506973267
# Epoch: 93
# train loss Discriminator 0.5358753204345703
# train loss Generator 0.3908972442150116
# Epoch: 93
# train loss Discriminator 0.5959068536758423
# train loss Generator 0.3559243679046631
# Epoch: 93
# train loss Discriminator 0.6098312139511108
# train loss Generator 0.3559243679046631
# Epoch: 93
# train loss Discriminator 0.6355045437812805
# train loss Generator 0.4232454299926758
# Epoch: 93
# train loss Discriminator 0.5438852310180664
# train loss Generator 0.44169074296951294
# Epoch: 93
# train loss Discriminator 0.47538328170776367
# train loss Generator 0.35148200392723083
# Epoch: 93
# train loss Discriminator 0.5995969772338867
# train loss Generator 0.4388481378555298
# Epoch : 93 , MAE val:  0.8389264192005017
# Epoch : 93 , RMSE val:  0.8389264192005017
# Epoch : 93 , MAPE val:  -0.5518721500215562
# Epoch : 93 , AR val:  -0.022011643001060732
# Epoch: 94
# train loss Discriminator 0.5565428733825684
# train loss Generator 0.32105565071105957
# Epoch: 94
# train loss Discriminator 0.4852297902107239
# train loss Generator 0.38436490297317505
# Epoch: 94
# train loss Discriminator 0.42239102721214294
# train loss Generator 0.4661003351211548
# Epoch: 94
# train loss Discriminator 0.5310118198394775
# train loss Generator 0.30962511897087097
# Epoch: 94
# train loss Discriminator 0.6134530305862427
# train loss Generator 0.30962511897087097
# Epoch: 94
# train loss Discriminator 0.4772954285144806
# train loss Generator 0.32798081636428833
# Epoch: 94
# train loss Discriminator 0.731479287147522
# train loss Generator 0.4297538697719574
# Epoch: 94
# train loss Discriminator 0.5263752937316895
# train loss Generator 0.4753316044807434
# Epoch: 94
# train loss Discriminator 0.5758112072944641
# train loss Generator 0.4101027846336365
# Epoch: 94
# train loss Discriminator 0.5506546497344971
# train loss Generator 0.4101027846336365
# Epoch: 94
# train loss Discriminator 0.5170923471450806
# train loss Generator 0.39584583044052124
# Epoch: 94
# train loss Discriminator 0.5175277590751648
# train loss Generator 0.3932616412639618
# Epoch: 94
# train loss Discriminator 0.5714741349220276
# train loss Generator 0.48659834265708923
# Epoch: 94
# train loss Discriminator 0.5667047500610352
# train loss Generator 0.40171217918395996
# Epoch: 94
# train loss Discriminator 0.4460197687149048
# train loss Generator 0.40171217918395996
# Epoch: 94
# train loss Discriminator 0.5110987424850464
# train loss Generator 0.4587177634239197
# Epoch: 94
# train loss Discriminator 0.45713692903518677
# train loss Generator 0.4411461055278778
# Epoch: 94
# train loss Discriminator 0.5551886558532715
# train loss Generator 0.3400302529335022
# Epoch: 94
# train loss Discriminator 0.44925588369369507
# train loss Generator 0.5151810050010681
# Epoch : 94 , MAE val:  0.8395388190830616
# Epoch : 94 , RMSE val:  0.8395388190830616
# Epoch : 94 , MAPE val:  -0.5408183758035022
# Epoch : 94 , AR val:  -0.018568155311219147
# Epoch: 95
# train loss Discriminator 0.5846364498138428
# train loss Generator 0.3742768168449402
# Epoch: 95
# train loss Discriminator 0.5214723944664001
# train loss Generator 0.3897889256477356
# Epoch: 95
# train loss Discriminator 0.5840073227882385
# train loss Generator 0.32187533378601074
# Epoch: 95
# train loss Discriminator 0.5273475646972656
# train loss Generator 0.3938421607017517
# Epoch: 95
# train loss Discriminator 0.6443402767181396
# train loss Generator 0.3938421607017517
# Epoch: 95
# train loss Discriminator 0.5034677386283875
# train loss Generator 0.457680881023407
# Epoch: 95
# train loss Discriminator 0.6293827891349792
# train loss Generator 0.30229073762893677
# Epoch: 95
# train loss Discriminator 0.6419639587402344
# train loss Generator 0.48141390085220337
# Epoch: 95
# train loss Discriminator 0.5643126368522644
# train loss Generator 0.34819135069847107
# Epoch: 95
# train loss Discriminator 0.4533185064792633
# train loss Generator 0.34819135069847107
# Epoch: 95
# train loss Discriminator 0.5857946872711182
# train loss Generator 0.4403422474861145
# Epoch: 95
# train loss Discriminator 0.5036133527755737
# train loss Generator 0.40618079900741577
# Epoch: 95
# train loss Discriminator 0.5602425336837769
# train loss Generator 0.3727140426635742
# Epoch: 95
# train loss Discriminator 0.43998008966445923
# train loss Generator 0.4188413619995117
# Epoch: 95
# train loss Discriminator 0.5344351530075073
# train loss Generator 0.4188413619995117
# Epoch: 95
# train loss Discriminator 0.5755720138549805
# train loss Generator 0.38706526160240173
# Epoch: 95
# train loss Discriminator 0.5089662671089172
# train loss Generator 0.4519209861755371
# Epoch: 95
# train loss Discriminator 0.5032373666763306
# train loss Generator 0.4284888505935669
# Epoch: 95
# train loss Discriminator 0.5150672197341919
# train loss Generator 0.35566702485084534
# Epoch : 95 , MAE val:  0.8387550074929245
# Epoch : 95 , RMSE val:  0.8387550074929245
# Epoch : 95 , MAPE val:  -0.5512281940780804
# Epoch : 95 , AR val:  -0.022262071916084536
# Epoch: 96
# train loss Discriminator 0.47154635190963745
# train loss Generator 0.44399935007095337
# Epoch: 96
# train loss Discriminator 0.48300057649612427
# train loss Generator 0.5157989263534546
# Epoch: 96
# train loss Discriminator 0.5763538479804993
# train loss Generator 0.3759382963180542
# Epoch: 96
# train loss Discriminator 0.5351049900054932
# train loss Generator 0.3424871265888214
# Epoch: 96
# train loss Discriminator 0.5834126472473145
# train loss Generator 0.3424871265888214
# Epoch: 96
# train loss Discriminator 0.5146677494049072
# train loss Generator 0.36815810203552246
# Epoch: 96
# train loss Discriminator 0.5031077265739441
# train loss Generator 0.49659284949302673
# Epoch: 96
# train loss Discriminator 0.5779199004173279
# train loss Generator 0.3887944221496582
# Epoch: 96
# train loss Discriminator 0.5180880427360535
# train loss Generator 0.4239468574523926
# Epoch: 96
# train loss Discriminator 0.5784516334533691
# train loss Generator 0.4239468574523926
# Epoch: 96
# train loss Discriminator 0.582971453666687
# train loss Generator 0.3758164644241333
# Epoch: 96
# train loss Discriminator 0.5883426070213318
# train loss Generator 0.43642568588256836
# Epoch: 96
# train loss Discriminator 0.522197961807251
# train loss Generator 0.4032534658908844
# Epoch: 96
# train loss Discriminator 0.56067955493927
# train loss Generator 0.3007870316505432
# Epoch: 96
# train loss Discriminator 0.6546119451522827
# train loss Generator 0.3007870316505432
# Epoch: 96
# train loss Discriminator 0.6860026121139526
# train loss Generator 0.5818004608154297
# Epoch: 96
# train loss Discriminator 0.617333173751831
# train loss Generator 0.45169851183891296
# Epoch: 96
# train loss Discriminator 0.5567513108253479
# train loss Generator 0.38769111037254333
# Epoch: 96
# train loss Discriminator 0.49792927503585815
# train loss Generator 0.4289361834526062
# Epoch : 96 , MAE val:  0.8395856747739857
# Epoch : 96 , RMSE val:  0.8395856747739857
# Epoch : 96 , MAPE val:  -0.5487496182644613
# Epoch : 96 , AR val:  -0.020294919447673216
# Epoch: 97
# train loss Discriminator 0.6355636715888977
# train loss Generator 0.368593692779541
# Epoch: 97
# train loss Discriminator 0.464491069316864
# train loss Generator 0.42641815543174744
# Epoch: 97
# train loss Discriminator 0.41373908519744873
# train loss Generator 0.4822985529899597
# Epoch: 97
# train loss Discriminator 0.6191818714141846
# train loss Generator 0.3733748495578766
# Epoch: 97
# train loss Discriminator 0.5397665500640869
# train loss Generator 0.3733748495578766
# Epoch: 97
# train loss Discriminator 0.5097881555557251
# train loss Generator 0.4080270528793335
# Epoch: 97
# train loss Discriminator 0.4427637457847595
# train loss Generator 0.5111411809921265
# Epoch: 97
# train loss Discriminator 0.5543251037597656
# train loss Generator 0.4187731146812439
# Epoch: 97
# train loss Discriminator 0.49611788988113403
# train loss Generator 0.584720253944397
# Epoch: 97
# train loss Discriminator 0.4726604223251343
# train loss Generator 0.584720253944397
# Epoch: 97
# train loss Discriminator 0.5111656785011292
# train loss Generator 0.5168365240097046
# Epoch: 97
# train loss Discriminator 0.7058883905410767
# train loss Generator 0.3017116189002991
# Epoch: 97
# train loss Discriminator 0.6138321757316589
# train loss Generator 0.3828112483024597
# Epoch: 97
# train loss Discriminator 0.5803081393241882
# train loss Generator 0.48601293563842773
# Epoch: 97
# train loss Discriminator 0.4660567045211792
# train loss Generator 0.48601293563842773
# Epoch: 97
# train loss Discriminator 0.7489606142044067
# train loss Generator 0.33790677785873413
# Epoch: 97
# train loss Discriminator 0.6993438601493835
# train loss Generator 0.35373902320861816
# Epoch: 97
# train loss Discriminator 0.47406548261642456
# train loss Generator 0.43354976177215576
# Epoch: 97
# train loss Discriminator 0.5523879528045654
# train loss Generator 0.3276425004005432
# Epoch : 97 , MAE val:  0.8411753736261306
# Epoch : 97 , RMSE val:  0.8411753736261306
# Epoch : 97 , MAPE val:  -0.5356725524508752
# Epoch : 97 , AR val:  -0.020488686068895194
# Epoch: 98
# train loss Discriminator 0.4890514314174652
# train loss Generator 0.4500839114189148
# Epoch: 98
# train loss Discriminator 0.5518081188201904
# train loss Generator 0.6272178292274475
# Epoch: 98
# train loss Discriminator 0.47916966676712036
# train loss Generator 0.389119416475296
# Epoch: 98
# train loss Discriminator 0.4355543851852417
# train loss Generator 0.42187851667404175
# Epoch: 98
# train loss Discriminator 0.47428518533706665
# train loss Generator 0.42187851667404175
# Epoch: 98
# train loss Discriminator 0.4538334012031555
# train loss Generator 0.4544612467288971
# Epoch: 98
# train loss Discriminator 0.5813981294631958
# train loss Generator 0.35948148369789124
# Epoch: 98
# train loss Discriminator 0.5732674598693848
# train loss Generator 0.5454233288764954
# Epoch: 98
# train loss Discriminator 0.6230760216712952
# train loss Generator 0.39115282893180847
# Epoch: 98
# train loss Discriminator 0.5594860911369324
# train loss Generator 0.39115282893180847
# Epoch: 98
# train loss Discriminator 0.5291860103607178
# train loss Generator 0.3562880754470825
# Epoch: 98
# train loss Discriminator 0.6383121013641357
# train loss Generator 0.41455820202827454
# Epoch: 98
# train loss Discriminator 0.5098364949226379
# train loss Generator 0.38314202427864075
# Epoch: 98
# train loss Discriminator 0.5468378067016602
# train loss Generator 0.4452260732650757
# Epoch: 98
# train loss Discriminator 0.5056116580963135
# train loss Generator 0.4452260732650757
# Epoch: 98
# train loss Discriminator 0.6153347492218018
# train loss Generator 0.3017496168613434
# Epoch: 98
# train loss Discriminator 0.5816563367843628
# train loss Generator 0.3338885009288788
# Epoch: 98
# train loss Discriminator 0.5731260776519775
# train loss Generator 0.4775121808052063
# Epoch: 98
# train loss Discriminator 0.5950648784637451
# train loss Generator 0.30397433042526245
# Epoch : 98 , MAE val:  0.841307961012944
# Epoch : 98 , RMSE val:  0.841307961012944
# Epoch : 98 , MAPE val:  -0.5342883474592651
# Epoch : 98 , AR val:  -0.02246048475976147
# Epoch: 99
# train loss Discriminator 0.5915689468383789
# train loss Generator 0.42429113388061523
# Epoch: 99
# train loss Discriminator 0.54048752784729
# train loss Generator 0.39875683188438416
# Epoch: 99
# train loss Discriminator 0.5113956928253174
# train loss Generator 0.34179970622062683
# Epoch: 99
# train loss Discriminator 0.5425935983657837
# train loss Generator 0.4034707248210907
# Epoch: 99
# train loss Discriminator 0.567857027053833
# train loss Generator 0.4034707248210907
# Epoch: 99
# train loss Discriminator 0.44020983576774597
# train loss Generator 0.4352397322654724
# Epoch: 99
# train loss Discriminator 0.7083231210708618
# train loss Generator 0.49138665199279785
# Epoch: 99
# train loss Discriminator 0.5374694466590881
# train loss Generator 0.33333420753479004
# Epoch: 99
# train loss Discriminator 0.5162079334259033
# train loss Generator 0.3717277944087982
# Epoch: 99
# train loss Discriminator 0.48086756467819214
# train loss Generator 0.3717277944087982
# Epoch: 99
# train loss Discriminator 0.4931350350379944
# train loss Generator 0.4452572464942932
# Epoch: 99
# train loss Discriminator 0.5656673908233643
# train loss Generator 0.41277778148651123
# Epoch: 99
# train loss Discriminator 0.5007475018501282
# train loss Generator 0.40477481484413147
# Epoch: 99
# train loss Discriminator 0.5265045166015625
# train loss Generator 0.38270309567451477
# Epoch: 99
# train loss Discriminator 0.4930431842803955
# train loss Generator 0.38270309567451477
# Epoch: 99
# train loss Discriminator 0.5160802006721497
# train loss Generator 0.3756658136844635
# Epoch: 99
# train loss Discriminator 0.5153668522834778
# train loss Generator 0.43736428022384644
# Epoch: 99
# train loss Discriminator 0.48831599950790405
# train loss Generator 0.3553263545036316
# Epoch: 99
# train loss Discriminator 0.5385438799858093
# train loss Generator 0.4166850447654724
# Epoch : 99 , MAE val:  0.8422857920912311
# Epoch : 99 , RMSE val:  0.8422857920912311
# Epoch : 99 , MAPE val:  -0.5267798192315924
# Epoch : 99 , AR val:  -0.018696040583070346

# %% [markdown]
# Validation of the model for SSE close price

# %%
print('Epoch :',epoch,', MAE val: ',mae_test)
print('Epoch :',epoch,', RMSE val: ',rmse_test)
print('Epoch :',epoch,', MAPE val: ',mape_test)
print('Epoch :',epoch,', AR val: ',ar_test)
# Out:
# Epoch : 99 , MAE val:  0.8422857920912311
# Epoch : 99 , RMSE val:  0.8422857920912311
# Epoch : 99 , MAPE val:  -0.5267798192315924
# Epoch : 99 , AR val:  -0.018696040583070346

# %%
val_dataset=StockDataset(SSE[2000:])
val_dataset.data=val_dataset.data.reset_index().drop('index',axis=1)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)

generator.eval()

generated_seqeunce_val=[]
target_seqeunce_val=[]
with torch.no_grad():

  mae_test=0
  rmse_test=0
  mape_test=0
  ar_test=0
  for iter, batch in enumerate(val_loader):
      data, target=batch
      data = data.to(device)
      target = target.to(device)
      generator_output=generator(data).detach()         
      generator_output= generator_output.squeeze(0)
     
      generated_seqeunce_val.append(generator_output.item())  
      target_seqeunce_val.append(target.item()) 
      
      mae_test+=torch.mean(torch.abs(generator_output-target)).item()
      rmse_test += torch.sqrt(torch.mean((generator_output-target)**2)).item()
      mape_test+=torch.mean(torch.abs(generator_output-target)/(target+0.0000001)).item()
      if iter>0:
          if generated_seqeunce_val[iter]>generated_seqeunce_val[iter-1]:
              ar_test+=target_seqeunce_val[iter]-target_seqeunce_val[iter-1]
      
  mae_test=mae_test/len(val_loader)
  rmse_test=rmse_test/len(val_loader)
  mape_test=mape_test/len(val_loader)
  ar_test=ar_test/(len(val_loader)-1)
  print('MAE val: ',mae_test)
  print('RMSE val: ',rmse_test)
  print('MAPE val: ',mape_test)
  print('AR val: ',ar_test)



  #print(f'Epoch {epoch} \t Train loss {train_loss} \t Test loss {test_loss}')
# Out:
# MAE val:  0.8422857920912311
# RMSE val:  0.8422857920912311
# MAPE val:  -0.5267798192315924
# AR val:  -0.018696040583070346

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel('time')
plt.ylabel('Close price')
plt.figure(figsize=[8,8])
plt.title('Generated close price vs true sequence')
plt.plot(generated_seqeunce_val*SSE.loc[2000+5:,'STD5_close']+SSE.loc[2000+5:,'MA5_close'],label='generated',c='blue')
plt.plot(SSE.loc[2000+5:,'Close'], label='true target',c='red')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, axs=plt.subplots(nrows=1,ncols=2,figsize=[12,6])

axs[0].set_title('Train loss Discriminator')
axs[0].plot(train_loss_disc)
axs[1].set_title('Train loss Generator')
axs[1].plot(train_loss_gen)

#
axs[1].set_xlabel('time')
axs[0].set_xlabel('time')
axs[0].set_ylabel('Train Loss')
axs[1].set_ylabel('Train Loss')
# Out:
# Text(0, 0.5, 'Train Loss')

# %%
train_all = DataLoader(train_dataset, batch_size=2000, shuffle=True)


for X_all, target in train_all:
  X_all,target=X_all.to(device),target.to(device)
  gen_output=generator(X_all)

# %%
gen_output=gen_output.detach().cpu().numpy()

# %%
list(gen_output.squeeze(1))*SSE.loc[6:2000, 'STD5_close']+SSE.loc[6:2000,'MA5_close']
# Out:
# 6       3218.273005
# 7       3224.964438
# 8       3225.109804
# 9       3228.399325
# 10      3226.350244
#            ...
# 1996    3215.308144
# 1997    3188.958803
# 1998    3148.735438
# 1999    3156.872737
# 2000    3157.255573
# Length: 1995, dtype: float64

# %%
plt.figure(figsize=[8,8])
plt.title('Training prediction')
plt.plot(list(gen_output.squeeze(1))*SSE.loc[6:2000, 'STD5_close']+SSE.loc[6:2000,'MA5_close'] ,label='generated on train')
plt.plot(SSE.loc[6:2000,'Close'],label='true price')
plt.legend()
plt.xlabel('time')
plt.ylabel('closing price')
# Out:
# Text(0, 0.5, 'closing price')

# %%
plt.plot(gen_output.detach().cpu(), label='generated x')
plt.plot(target.detach().cpu(), label='target')
plt.legend()

# %%
plot_diff=gen_output.squeeze(1).detach().cpu().numpy()-target.detach().cpu().numpy()
plt.plot(plot_diff)

# %%
plot_diff.shape
# Out:
# (1995,)

# %%
plt.hist(plot_diff,bins=40)
# Out:
# (array([10., 16., 28., 38., 29., 37., 49., 59., 67., 76., 77., 96., 99.,
#         89., 80., 47., 53., 48., 47., 47., 44., 49., 38., 58., 62., 80.,
#         72., 89., 57., 67., 65., 54., 64., 52., 22., 10.,  9.,  7.,  3.,
#          1.]),
#  array([-1.7531173 , -1.6488959 , -1.5446744 , -1.4404529 , -1.3362315 ,
#         -1.2320101 , -1.1277887 , -1.0235672 , -0.91934574, -0.8151243 ,
#         -0.7109028 , -0.60668135, -0.5024599 , -0.39823845, -0.29401702,
#         -0.18979555, -0.08557411,  0.01864735,  0.1228688 ,  0.22709025,
#          0.3313117 ,  0.43553317,  0.5397546 ,  0.64397603,  0.7481975 ,
#          0.85241896,  0.9566404 ,  1.0608618 ,  1.1650833 ,  1.2693048 ,
#          1.3735262 ,  1.4777477 ,  1.5819691 ,  1.6861906 ,  1.7904121 ,
#          1.8946335 ,  1.9988549 ,  2.1030765 ,  2.2072978 ,  2.3115194 ,
#          2.4157407 ], dtype=float32),
#  <a list of 40 Patch objects>)
